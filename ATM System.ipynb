# %%
print("welcome to SBI Atm")
name = input("please enter your name")
bal = 50000
for i in range(1,4):
    pin = int(input("enter your login pin"))
    if pin == 2005 :
        amount = int(input("enter your amount"))
        print('hello',name,"your availabel bal is :",bal)
        for i in range(1,4):
            trans_pin = int(input("enter your transition pin"))
            if bal > amount + 10000 and trans_pin == 2320 :
                bal = bal-amount 
                print("withdraw succesfully ")
                print("your current balance is :",bal)
                break
            else:
                print("insufficent blance")
        break
    else:
        print("u have enter wrong pin enter your right pin")
# Out:
# welcome to SBI Atm
# please enter your name Lokesh Suresh Hongure
# enter your login pin 2005
# enter your amount 5000
# hello Lokesh Suresh Hongure your availabel bal is : 50000
# enter your transition pin 2320
# withdraw succesfully
# your current balance is : 45000
